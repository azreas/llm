# %%
import torch
from modelscope import AutoModelForCausalLM, AutoTokenizer
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
device = "cuda"
tokenizer = AutoTokenizer.from_pretrained("ZhipuAI/glm-4-9b-chat",trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    "ZhipuAI/glm-4-9b-chat",
    torch_dtype=torch.float32,
    low_cpu_mem_usage=True,
    trust_remote_code=True
).to(device).eval()
print(model)
# Out:
# 2024-06-05 16:52:10,232 - modelscope - INFO - PyTorch version 2.3.0 Found.
# 2024-06-05 16:52:10,234 - modelscope - INFO - Loading ast index from /opt/cache/modelscope/hub/ast_indexer
# 2024-06-05 16:52:10,274 - modelscope - INFO - Loading done! Current index file version is 1.14.0, with md5 a5cc18d4387c78ee9f041e8332bb1697 and a total number of 976 components indexed
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/cuda/__init__.py:306, in _lazy_init()
#     305 try:
# --> 306     queued_call()
#     307 except Exception as e:
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/cuda/__init__.py:174, in _check_capability()
#     173 for d in range(device_count()):
# --> 174     capability = get_device_capability(d)
#     175     major = capability[0]
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/cuda/__init__.py:430, in get_device_capability(device)
#     418 r"""Get the cuda capability of a device.
#     419
#     420 Args:
#    (...)
#     428     tuple(int, int): the major and minor cuda capability of the device
#     429 """
# --> 430 prop = get_device_properties(device)
#     431 return prop.major, prop.minor
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/cuda/__init__.py:448, in get_device_properties(device)
#     447     raise AssertionError("Invalid device id")
# --> 448 return _get_device_properties(device)
#
# RuntimeError: device >= 0 && device < num_gpus INTERNAL ASSERT FAILED at "../aten/src/ATen/cuda/CUDAContext.cpp":50, please report a bug to PyTorch. device=, num_gpus=
#
# The above exception was the direct cause of the following exception:
#
# DeferredCudaCallError                     Traceback (most recent call last)
# Cell In[1], line 12
#       5 device = "cuda"
#       6 tokenizer = AutoTokenizer.from_pretrained("ZhipuAI/glm-4-9b-chat",trust_remote_code=True)
#       7 model = AutoModelForCausalLM.from_pretrained(
#       8     "ZhipuAI/glm-4-9b-chat",
#       9     torch_dtype=torch.float32,
#      10     low_cpu_mem_usage=True,
#      11     trust_remote_code=True
# ---> 12 ).to(device).eval()
#      13 print(model)
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/transformers/modeling_utils.py:2724, in PreTrainedModel.to(self, *args, **kwargs)
#    2719     if dtype_present_in_args:
#    2720         raise ValueError(
#    2721             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    2722             " `dtype` by passing the correct `torch_dtype` argument."
#    2723         )
# -> 2724 return super().to(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/nn/modules/module.py:1173, in Module.to(self, *args, **kwargs)
#    1170         else:
#    1171             raise
# -> 1173 return self._apply(convert)
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/nn/modules/module.py:779, in Module._apply(self, fn, recurse)
#     777 if recurse:
#     778     for module in self.children():
# --> 779         module._apply(fn)
#     781 def compute_should_use_set_data(tensor, tensor_applied):
#     782     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     783         # If the new tensor has compatible tensor type as the existing tensor,
#     784         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     789         # global flag to let the user control whether they want the future
#     790         # behavior of overwriting the existing tensor or not.
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/nn/modules/module.py:779, in Module._apply(self, fn, recurse)
#     777 if recurse:
#     778     for module in self.children():
# --> 779         module._apply(fn)
#     781 def compute_should_use_set_data(tensor, tensor_applied):
#     782     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     783         # If the new tensor has compatible tensor type as the existing tensor,
#     784         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     789         # global flag to let the user control whether they want the future
#     790         # behavior of overwriting the existing tensor or not.
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/nn/modules/module.py:779, in Module._apply(self, fn, recurse)
#     777 if recurse:
#     778     for module in self.children():
# --> 779         module._apply(fn)
#     781 def compute_should_use_set_data(tensor, tensor_applied):
#     782     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     783         # If the new tensor has compatible tensor type as the existing tensor,
#     784         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     789         # global flag to let the user control whether they want the future
#     790         # behavior of overwriting the existing tensor or not.
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/nn/modules/module.py:804, in Module._apply(self, fn, recurse)
#     800 # Tensors stored in modules are graph leaves, and we don't want to
#     801 # track autograd history of `param_applied`, so we have to use
#     802 # `with torch.no_grad():`
#     803 with torch.no_grad():
# --> 804     param_applied = fn(param)
#     805 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     807 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/nn/modules/module.py:1159, in Module.to.<locals>.convert(t)
#    1152     if convert_to_format is not None and t.dim() in (4, 5):
#    1153         return t.to(
#    1154             device,
#    1155             dtype if t.is_floating_point() or t.is_complex() else None,
#    1156             non_blocking,
#    1157             memory_format=convert_to_format,
#    1158         )
# -> 1159     return t.to(
#    1160         device,
#    1161         dtype if t.is_floating_point() or t.is_complex() else None,
#    1162         non_blocking,
#    1163     )
#    1164 except NotImplementedError as e:
#    1165     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# File ~/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/cuda/__init__.py:312, in _lazy_init()
#     307         except Exception as e:
#     308             msg = (
#     309                 f"CUDA call failed lazily at initialization with error: {str(e)}\n\n"
#     310                 f"CUDA call was originally invoked at:\n\n{''.join(orig_traceback)}"
#     311             )
# --> 312             raise DeferredCudaCallError(msg) from e
#     313 finally:
#     314     delattr(_tls, "is_initializing")
#
# DeferredCudaCallError: CUDA call failed lazily at initialization with error: device >= 0 && device < num_gpus INTERNAL ASSERT FAILED at "../aten/src/ATen/cuda/CUDAContext.cpp":50, please report a bug to PyTorch. device=, num_gpus=
#
# CUDA call was originally invoked at:
#
#   File "/home/xuzijie/.pyenv/versions/3.10.14/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/xuzijie/.pyenv/versions/3.10.14/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/xuzijie/.pyenv/versions/3.10.14/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/xuzijie/.pyenv/versions/3.10.14/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/xuzijie/.pyenv/versions/3.10.14/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2314187/3801500798.py", line 1, in <module>
#     import torch
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/__init__.py", line 1478, in <module>
#     _C._initExtension(manager_path())
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/cuda/__init__.py", line 238, in <module>
#     _lazy_call(_check_capability)
#   File "/home/xuzijie/.pyenv/versions/3.10.14/envs/xuzijie/lib/python3.10/site-packages/torch/cuda/__init__.py", line 235, in _lazy_call
#     _queued_calls.append((callable, traceback.format_stack()))
